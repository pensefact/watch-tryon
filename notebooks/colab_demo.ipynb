# %% [markdown]
# # Watch Try-On POC — Colab Demo
#
# Run this notebook on a **GPU runtime** (T4 free tier is fine).
#
# 1. Clone the repo & install deps
# 2. Set your PiAPI key
# 3. Download SAM 2 weights
# 4. Launch Gradio with a public URL

# %%
# Verify GPU
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader

# %%
# Clone repo
# !git clone https://github.com/pensefact/watch-tryon.git
# %cd watch-tryon

# %%
# Install dependencies
# !pip install -q -r requirements.txt
# !pip install -q torch torchvision --index-url https://download.pytorch.org/whl/cu121
# !pip install -q "mediapipe>=0.10,<1.0"

# %%
# Install SAM 2
# !pip install -q sam2

# %%
# Download SAM 2 checkpoint (sam2_hiera_large)
import os
os.makedirs('checkpoints', exist_ok=True)
# !wget -q -O checkpoints/sam2_hiera_large.pt \
  https://dl.fbaipublicfiles.com/segment_anything_2/072824/sam2_hiera_large.pt
print('SAM 2 weights downloaded:', os.path.getsize('checkpoints/sam2_hiera_large.pt') / 1e9, 'GB')

# %%
# Install Blender (headless)
# !apt-get update -qq && apt-get install -qq -y blender > /dev/null 2>&1
# !blender --version

# %%
# Set your PiAPI key (for watch 3D reconstruction)
# Get one at https://piapi.ai — $0.10 per generation
import os
os.environ['PIAPI_API_KEY'] = ''  # <-- paste your key here

# %%
# Run tests to verify everything works
# !python -m pytest tests/ -v

# %%
# Launch Gradio app with public URL
import subprocess
import sys

# Patch app.py to use share=True
with open('src/app.py', 'r') as f:
    app_code = f.read()
app_code = app_code.replace('.launch()', '.launch(share=True)')
with open('src/app.py', 'w') as f:
    f.write(app_code)

# Run it
# !python -m src.app
